# %% [markdown]
# ## Exploratory Data Analysis for PMF Dataset

# %% [markdown]
# The following notebook explores the SY 2018-19 Performance Management Framework (PMF) Dataset published by the DC Public Charter School Board (DC PCSB). The analysis and likely model will be limited to schools serving students in grades PK - 8. Additional features may be added in the coming days / weeks.

# %%
import pandas as pd
import seaborn as sns
from sklearn.feature_selection import SelectFromModel
# %matplotlib inline

# %% [markdown]
# ### Read in Data

# %%
pmf_data = pd.read_csv('../pmf-predictions/SY2018-19 Charter Sector PMF Datafile.csv')
pmf_data.head(5)
# Out:
#    School Code                                        School Name School Year  \
# 0          217  Achievement Preparatory Academy PCS - Wahler P...   2018-2019
# 1         1100  Achievement Preparatory Academy PCS - Wahler P...   2018-2019
# 2         3068                                       BASIS DC PCS   2018-2019
# 3          142                                        Bridges PCS   2018-2019
# 4          184                    Capital City PCS - Lower School   2018-2019
#
#   PMF Score  PMF Tier Framework  Ward  Money Spent on Personnel (%)  \
# 0    60.10%       2.0      PK-8     8                     51.360076
# 1    35.30%       2.0      PK-8     8                     51.360076
# 2    84.30%       1.0      PK-8     2                     57.726752
# 3    50.00%       2.0      PK-8     5                     68.766596
# 4    56.70%       2.0      PK-8     4                     70.450341
#
#    Asian (%)  Black / African American (%)  ...  Growth Assessment  \
# 0        0.0                          97.1  ...           NWEA MAP
# 1        0.0                          97.6  ...              PARCC
# 2        7.2                          33.8  ...              PARCC
# 3        1.2                          51.9  ...              PARCC
# 4        1.9                          32.2  ...              PARCC
#
#    ELA Growth (%)  Math Growth (%)  Achievement Assessment  ELA Levels 3+ (%)  \
# 0            63.5             65.0                   PARCC               32.3
# 1            41.1             42.5                   PARCC               39.9
# 2            62.5             52.5                   PARCC               94.6
# 3            46.1             42.9                   PARCC               43.2
# 4            51.8             43.0                   PARCC               47.5
#
#    ELA Levels 4+ (%)  Math Levels 3+ (%)  Math Levels 4+ (%)  \
# 0               14.5                48.4                19.4
# 1               19.5                35.0                12.5
# 2               79.5                88.7                67.6
# 3               19.4                51.4                19.6
# 4               15.2                52.5                28.3
#
#    Attendance (ISA) (%) Reenrollment Rate (%)
# 0                  88.8                  64.4
# 1                  91.3                  80.2
# 2                  96.6                  90.0
# 3                  93.6                  78.4
# 4                  93.6                  89.9
#
# [5 rows x 29 columns]

# %%
## Set Index to the unique School Codes
pmf_data.set_index(['School Code', 'School Year'], inplace= True)

# %%
##check to make sure dataset is a pandas dataframe
type(pmf_data)
# Out:
# pandas.core.frame.DataFrame

# %%
## check the number of rows and columns
pmf_data.shape
# Out:
# (146, 27)

# %% [markdown]
# ### Columns & Data Types

# %%
##print columns
pmf_data.columns
## NOTE: Potential to add additional features once I have a chance to join them to the dataset
# Out:
# Index(['School Name', 'PMF Score', 'PMF Tier', 'Framework', 'Ward',
#        'Money Spent on Personnel (%)', 'Asian (%)',
#        'Black / African American (%)', 'Hispanic (%)', 'Native American (%)',
#        'Pacific Islander / Native Hawaiian (%)', 'White (%)',
#        'Multiracial (%)', 'SPED (%)', 'ELL (%)', 'At Risk (%)',
#        'Audited Enrollment (#)', 'Growth Assessment', 'ELA Growth (%)',
#        'Math Growth (%)', 'Achievement Assessment', 'ELA Levels 3+ (%)',
#        'ELA Levels 4+ (%)', 'Math Levels 3+ (%)', 'Math Levels 4+ (%)',
#        'Attendance (ISA) (%)', 'Reenrollment Rate (%)'],
#       dtype='object')

# %%
##Get list of all columns and corresponding data types
pd.DataFrame(pmf_data.dtypes,columns=['Data Types'])
# Out:
#                                        Data Types
# School Name                                object
# PMF Score                                  object
# PMF Tier                                  float64
# Framework                                  object
# Ward                                        int64
# Money Spent on Personnel (%)              float64
# Asian (%)                                 float64
# Black / African American (%)              float64
# Hispanic (%)                              float64
# Native American (%)                       float64
# Pacific Islander / Native Hawaiian (%)    float64
# White (%)                                 float64
# Multiracial (%)                           float64
# SPED (%)                                  float64
# ELL (%)                                   float64
# At Risk (%)                               float64
# Audited Enrollment (#)                      int64
# Growth Assessment                          object
# ELA Growth (%)                            float64
# Math Growth (%)                           float64
# Achievement Assessment                     object
# ELA Levels 3+ (%)                         float64
# ELA Levels 4+ (%)                         float64
# Math Levels 3+ (%)                        float64
# Math Levels 4+ (%)                        float64
# Attendance (ISA) (%)                      float64
# Reenrollment Rate (%)                     float64

# %%
##Remove % from PMF Score Column
pmf_data['PMF Score'] = pmf_data['PMF Score'].str.replace('%','')

# %%
##Check to see if replace worked
pmf_data.head(3)
# Out:
#                                                                School Name  \
# School Code School Year
# 217         2018-2019    Achievement Preparatory Academy PCS - Wahler P...
# 1100        2018-2019    Achievement Preparatory Academy PCS - Wahler P...
# 3068        2018-2019                                         BASIS DC PCS
#
#                         PMF Score  PMF Tier Framework  Ward  \
# School Code School Year
# 217         2018-2019       60.10       2.0      PK-8     8
# 1100        2018-2019       35.30       2.0      PK-8     8
# 3068        2018-2019       84.30       1.0      PK-8     2
#
#                          Money Spent on Personnel (%)  Asian (%)  \
# School Code School Year
# 217         2018-2019                       51.360076        0.0
# 1100        2018-2019                       51.360076        0.0
# 3068        2018-2019                       57.726752        7.2
#
#                          Black / African American (%)  Hispanic (%)  \
# School Code School Year
# 217         2018-2019                            97.1           1.9
# 1100        2018-2019                            97.6           0.7
# 3068        2018-2019                            33.8           8.6
#
#                          Native American (%)  ...  Growth Assessment  \
# School Code School Year                       ...
# 217         2018-2019                    0.5  ...           NWEA MAP
# 1100        2018-2019                    0.4  ...              PARCC
# 3068        2018-2019                    0.6  ...              PARCC
#
#                          ELA Growth (%)  Math Growth (%)  \
# School Code School Year
# 217         2018-2019              63.5             65.0
# 1100        2018-2019              41.1             42.5
# 3068        2018-2019              62.5             52.5
#
#                          Achievement Assessment  ELA Levels 3+ (%)  \
# School Code School Year
# 217         2018-2019                     PARCC               32.3
# 1100        2018-2019                     PARCC               39.9
# 3068        2018-2019                     PARCC               94.6
#
#                          ELA Levels 4+ (%)  Math Levels 3+ (%)  \
# School Code School Year
# 217         2018-2019                 14.5                48.4
# 1100        2018-2019                 19.5                35.0
# 3068        2018-2019                 79.5                88.7
#
#                         Math Levels 4+ (%)  Attendance (ISA) (%)  \
# School Code School Year
# 217         2018-2019                 19.4                  88.8
# 1100        2018-2019                 12.5                  91.3
# 3068        2018-2019                 67.6                  96.6
#
#                          Reenrollment Rate (%)
# School Code School Year
# 217         2018-2019                     64.4
# 1100        2018-2019                     80.2
# 3068        2018-2019                     90.0
#
# [3 rows x 27 columns]

# %%
## Convert PMF Score to a numeric feature
pmf_data['PMF Score'] = pd.to_numeric(pmf_data['PMF Score'])
pmf_data['PMF Score'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Descriptive Stats of PMF Dataset

# %%
##key features
pmf_data[['PMF Score','PMF Tier','Ward','SPED (%)','At Risk (%)','ELL (%)','Audited Enrollment (#)','ELA Growth (%)','Math Growth (%)']].describe()
# Out:
#         PMF Score    PMF Tier        Ward    SPED (%)  At Risk (%)  \
# count  146.000000  146.000000  146.000000  146.000000   146.000000
# mean    60.702055    1.623288    5.513699   15.763014    46.607534
# std     15.178835    0.552616    1.750808    5.532949    19.830360
# min     20.800000    1.000000    1.000000    4.200000     4.700000
# 25%     50.150000    1.000000    5.000000   11.925000    33.800000
# 50%     60.800000    2.000000    5.000000   15.300000    51.200000
# 75%     71.700000    2.000000    7.000000   19.100000    60.900000
# max     93.800000    3.000000    8.000000   39.100000    82.900000
#
#           ELL (%)  Audited Enrollment (#)  ELA Growth (%)  Math Growth (%)
# count  146.000000              146.000000      146.000000       146.000000
# mean     8.092466              372.164384       52.440000        53.384138
# std     11.906284              147.591189       10.425866        13.653822
# min      0.000000               94.000000       29.600000        24.500000
# 25%      0.425000              262.250000       45.350000        44.850000
# 50%      2.300000              350.000000       50.900000        50.900000
# 75%     10.800000              456.000000       59.500000        57.500000
# max     48.800000             1061.000000       83.000000        94.000000

# %%
## All Features
pmf_data.describe()
# Out:
#         PMF Score    PMF Tier        Ward  Money Spent on Personnel (%)  \
# count  146.000000  146.000000  146.000000                    146.000000
# mean    60.702055    1.623288    5.513699                     61.942155
# std     15.178835    0.552616    1.750808                      7.798688
# min     20.800000    1.000000    1.000000                     27.508852
# 25%     50.150000    1.000000    5.000000                     60.758005
# 50%     60.800000    2.000000    5.000000                     63.147965
# 75%     71.700000    2.000000    7.000000                     66.446471
# max     93.800000    3.000000    8.000000                     70.975664
#
#         Asian (%)  Black / African American (%)  Hispanic (%)  \
# count  146.000000                    146.000000    146.000000
# mean     0.876712                     76.593151     12.036986
# std      1.641448                     26.600785     16.288773
# min      0.000000                     17.200000      0.000000
# 25%      0.000000                     51.900000      1.825000
# 50%      0.200000                     92.450000      5.100000
# 75%      1.100000                     97.300000     11.750000
# max      9.800000                    100.000000     78.600000
#
#        Native American (%)  Pacific Islander / Native Hawaiian (%)  \
# count           146.000000                              146.000000
# mean              0.196575                                0.075342
# std               0.357851                                0.171227
# min               0.000000                                0.000000
# 25%               0.000000                                0.000000
# 50%               0.000000                                0.000000
# 75%               0.300000                                0.000000
# max               2.100000                                1.100000
#
#         White (%)  ...  At Risk (%)  Audited Enrollment (#)  ELA Growth (%)  \
# count  146.000000  ...   146.000000              146.000000      146.000000
# mean     7.482192  ...    46.607534              372.164384       52.440000
# std     12.940733  ...    19.830360              147.591189       10.425866
# min      0.000000  ...     4.700000               94.000000       29.600000
# 25%      0.000000  ...    33.800000              262.250000       45.350000
# 50%      0.400000  ...    51.200000              350.000000       50.900000
# 75%      8.475000  ...    60.900000              456.000000       59.500000
# max     44.800000  ...    82.900000             1061.000000       83.000000
#
#        Math Growth (%)  ELA Levels 3+ (%)  ELA Levels 4+ (%)  \
# count       146.000000         146.000000         146.000000
# mean         53.384138          57.571918          32.380822
# std          13.653822          14.340085          14.001376
# min          24.500000          20.000000           6.500000
# 25%          44.850000          49.325000          21.100000
# 50%          50.900000          57.750000          31.450000
# 75%          57.500000          66.800000          40.500000
# max          94.000000          94.600000          79.500000
#
#        Math Levels 3+ (%)  Math Levels 4+ (%)  Attendance (ISA) (%)  \
# count          146.000000          146.000000            146.000000
# mean            58.594521           31.260959             93.205479
# std             16.423338           16.277585              1.918181
# min             18.500000            4.800000             88.400000
# 25%             48.675000           19.075000             92.200000
# 50%             57.450000           28.800000             93.300000
# 75%             69.300000           40.850000             94.175000
# max             91.800000           77.500000             99.800000
#
#        Reenrollment Rate (%)
# count             146.000000
# mean               84.376027
# std                 8.128929
# min                51.300000
# 25%                78.825000
# 50%                85.350000
# 75%                90.750000
# max                98.300000
#
# [8 rows x 23 columns]

# %% [markdown]
# #### Notes and observations

# %% [markdown]
# - There are 90 rows of data but only 85 have a PMF Tier. This means 5 schools were scored but not tiered in SY 2018-19. Schools in their first or last year of operation generally do not receive a corresponding Tier.
# - The average Ward for the PK-8 schools is 5.7 which corresponds to my intuition. A plurality, if not majority, of public charter schools in DC are located in Wards 5 and 6.
# - Whil each school's population is unique, the average population is 8.5% English Language Learners, 15.0% have a disability, and 46.9% are considered at-risk.
# - The median school size is 335 students.
# - On student growth measures of ELA and Math, 53.7% and 52.5%, respectively, are meeting growth expectations as evidenced by the median value.

# %% [markdown]
# ### Missing Data
# Grade configurations of each campus define what measures are in place for each school. Schools serving PK students, for example, receive a CLASS score but others do not. PK only schools also do not receive a reenrollment rate. Other examples include: K-2 students do not take the state assessment, new schools do not receive a Tier in their first year, and 3rd Graders / 8th Graders are the only students scored on "Gateway Achievement" measures. Some of this data can't just be filled in using the average. I will need to figure out how to model with missing data being an acceptable choice.

# %%
##view where most data is null
pmf_data.isnull()
# Out:
#                          School Name  PMF Score  PMF Tier  Framework   Ward  \
# School Code School Year
# 217         2018-2019          False      False     False      False  False
# 1100        2018-2019          False      False     False      False  False
# 3068        2018-2019          False      False     False      False  False
# 142         2018-2019          False      False     False      False  False
# 184         2018-2019          False      False     False      False  False
# ...                              ...        ...       ...        ...    ...
# 198         2017-2018          False      False     False      False  False
# 270         2017-2018          False      False     False      False  False
# 263         2017-2018          False      False     False      False  False
# 125         2017-2018          False      False     False      False  False
# 1117        2017-2018          False      False     False      False  False
#
#                          Money Spent on Personnel (%)  Asian (%)  \
# School Code School Year
# 217         2018-2019                           False      False
# 1100        2018-2019                           False      False
# 3068        2018-2019                           False      False
# 142         2018-2019                           False      False
# 184         2018-2019                           False      False
# ...                                               ...        ...
# 198         2017-2018                           False      False
# 270         2017-2018                           False      False
# 263         2017-2018                           False      False
# 125         2017-2018                           False      False
# 1117        2017-2018                           False      False
#
#                          Black / African American (%)  Hispanic (%)  \
# School Code School Year
# 217         2018-2019                           False         False
# 1100        2018-2019                           False         False
# 3068        2018-2019                           False         False
# 142         2018-2019                           False         False
# 184         2018-2019                           False         False
# ...                                               ...           ...
# 198         2017-2018                           False         False
# 270         2017-2018                           False         False
# 263         2017-2018                           False         False
# 125         2017-2018                           False         False
# 1117        2017-2018                           False         False
#
#                          Native American (%)  ...  Growth Assessment  \
# School Code School Year                       ...
# 217         2018-2019                  False  ...              False
# 1100        2018-2019                  False  ...              False
# 3068        2018-2019                  False  ...              False
# 142         2018-2019                  False  ...              False
# 184         2018-2019                  False  ...              False
# ...                                      ...  ...                ...
# 198         2017-2018                  False  ...              False
# 270         2017-2018                  False  ...              False
# 263         2017-2018                  False  ...              False
# 125         2017-2018                  False  ...              False
# 1117        2017-2018                  False  ...              False
#
#                          ELA Growth (%)  Math Growth (%)  \
# School Code School Year
# 217         2018-2019             False            False
# 1100        2018-2019             False            False
# 3068        2018-2019             False            False
# 142         2018-2019             False            False
# 184         2018-2019             False            False
# ...                                 ...              ...
# 198         2017-2018             False            False
# 270         2017-2018             False            False
# 263         2017-2018             False            False
# 125         2017-2018             False            False
# 1117        2017-2018             False            False
#
#                          Achievement Assessment  ELA Levels 3+ (%)  \
# School Code School Year
# 217         2018-2019                     False              False
# 1100        2018-2019                     False              False
# 3068        2018-2019                     False              False
# 142         2018-2019                     False              False
# 184         2018-2019                     False              False
# ...                                         ...                ...
# 198         2017-2018                     False              False
# 270         2017-2018                     False              False
# 263         2017-2018                     False              False
# 125         2017-2018                     False              False
# 1117        2017-2018                     False              False
#
#                          ELA Levels 4+ (%)  Math Levels 3+ (%)  \
# School Code School Year
# 217         2018-2019                False               False
# 1100        2018-2019                False               False
# 3068        2018-2019                False               False
# 142         2018-2019                False               False
# 184         2018-2019                False               False
# ...                                    ...                 ...
# 198         2017-2018                False               False
# 270         2017-2018                False               False
# 263         2017-2018                False               False
# 125         2017-2018                False               False
# 1117        2017-2018                False               False
#
#                          Math Levels 4+ (%)  Attendance (ISA) (%)  \
# School Code School Year
# 217         2018-2019                 False                 False
# 1100        2018-2019                 False                 False
# 3068        2018-2019                 False                 False
# 142         2018-2019                 False                 False
# 184         2018-2019                 False                 False
# ...                                     ...                   ...
# 198         2017-2018                 False                 False
# 270         2017-2018                 False                 False
# 263         2017-2018                 False                 False
# 125         2017-2018                 False                 False
# 1117        2017-2018                 False                 False
#
#                          Reenrollment Rate (%)
# School Code School Year
# 217         2018-2019                    False
# 1100        2018-2019                    False
# 3068        2018-2019                    False
# 142         2018-2019                    False
# 184         2018-2019                    False
# ...                                        ...
# 198         2017-2018                    False
# 270         2017-2018                    False
# 263         2017-2018                    False
# 125         2017-2018                    False
# 1117        2017-2018                    False
#
# [149 rows x 27 columns]

# %%
pmf_data.isnull().sum()
# Out:
# School Name                               0
# PMF Score                                 0
# PMF Tier                                  0
# Framework                                 0
# Ward                                      0
# Money Spent on Personnel (%)              0
# Asian (%)                                 0
# Black / African American (%)              0
# Hispanic (%)                              0
# Native American (%)                       0
# Pacific Islander / Native Hawaiian (%)    0
# White (%)                                 0
# Multiracial (%)                           0
# SPED (%)                                  0
# ELL (%)                                   0
# At Risk (%)                               0
# Audited Enrollment (#)                    0
# Growth Assessment                         0
# ELA Growth (%)                            0
# Math Growth (%)                           0
# Achievement Assessment                    0
# ELA Levels 3+ (%)                         0
# ELA Levels 4+ (%)                         0
# Math Levels 3+ (%)                        0
# Math Levels 4+ (%)                        0
# Attendance (ISA) (%)                      0
# Reenrollment Rate (%)                     0
# dtype: int64

# %%
## fill reenrollment rates & growth with average
pmf_data['Reenrollment Rate (%)'].fillna(pmf_data['Reenrollment Rate (%)'].mean(),inplace=True)
pmf_data['ELA Growth (%)'].fillna(pmf_data['ELA Growth (%)'].mean(),inplace=True)
pmf_data['Math Growth (%)'].fillna(pmf_data['Math Growth (%)'].mean(),inplace=True)
## remove schools with no tier
pmf_data.dropna(subset= ['PMF Tier'], inplace=True)
## Check for zero nulls 
pmf_data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Group By Frameworks and Wards
# PK Only (8 total) schools have a higher overall PMF score than PK-8 (82 total) schools. Schools in Ward 1 have an average PMF score that is below 60.0% -- the only Ward in DC this true for.

# %%
pmf_data[['Framework','PMF Score']].groupby('Framework').mean()
# Out:
#            PMF Score
# Framework
# PK-8       60.702055

# %%
pmf_data[['Ward','PMF Score']].groupby('Ward').mean()
# Out:
#       PMF Score
# Ward
# 1     50.328571
# 2     77.550000
# 4     62.111111
# 5     63.928889
# 6     61.866667
# 7     60.134783
# 8     54.358333

# %%
## only one campus in Ward 2 so the average is actually just one school
pmf_data['Ward'].value_counts()
# Out:
# 5    45
# 4    27
# 8    24
# 7    23
# 6    18
# 1     7
# 2     2
# Name: Ward, dtype: int64

# %%
pmf_data['Framework'].value_counts()
# Out:
# PK-8    146
# Name: Framework, dtype: int64

# %% [markdown]
# ## Data Visualizations

# %% [markdown]
# ### Distributions

# %%
#PMF Scores (doesn't appear to be a normal dist)
pmf_data['PMF Score'].plot(kind='hist',bins = 10);

# %%
pmf_data.hist(column='PMF Score',by='Ward',figsize=(16,16),bins = 5);

# %%
# % of students who are at-risk and their performance on the framework is a common discussion at DC PCSB
pmf_data['At Risk (%)'].plot(kind='hist',bins= 10);

# %%
##Check for outliers of special populations
special_pops = ['ELL (%)','At Risk (%)','SPED (%)']
pmf_data[special_pops].plot(kind='box');

# %% [markdown]
# ### Correlations
# In the following cells, I explore the correlation of different features in the dataset. Again, a particular concern is the at-risk special population. Maintaining a framework that isn't "biased" against any particular group of students is of utmost importance to the organization.

# %%
## View the percent of students at-risk and the campus PMF score on a scatter plot
pmf_data.plot(kind='scatter',x='At Risk (%)',y = 'PMF Score');

# %%
##This plot has too many features

pmf_data_correlations = pmf_data.corr();
sns.heatmap(pmf_data_correlations,cmap='Blues');

# %%
#narrow features
features = ['PMF Score','At Risk (%)','SPED (%)','ELL (%)','Ward','ELA Levels 3+ (%)',
           'Math Levels 3+ (%)','ELA Levels 4+ (%)','Math Levels 4+ (%)']

# %%
pmf_data_correlations = pmf_data[features].corr()
sns.heatmap(pmf_data_correlations, cmap = 'Blues',annot=True);

# %%
feature_cols = ['At Risk (%)','Ward','ELA Levels 4+ (%)','Math Levels 4+ (%)','Attendance (ISA) (%)','Money Spent on Personnel (%)']

# %%
X = pmf_data[feature_cols]
y = pmf_data['PMF Tier']
# Out:
# School Code  School Year
# 217          2018-2019      2.0
# 1100         2018-2019      2.0
# 3068         2018-2019      1.0
# 142          2018-2019      2.0
# 184          2018-2019      2.0
#                            ...
# 198          2017-2018      1.0
# 270          2017-2018      2.0
# 263          2017-2018      2.0
# 125          2017-2018      1.0
# 1117         2017-2018      1.0
# Name: PMF Tier, Length: 146, dtype: float64

# %% [markdown]
# ### Summary
#
# #### Shortcomings / Assumptions
# One issue I am going to have to solve for is the natural tendency for this dataset to have null values. For example, there are 71 rows with no value for PK Social Emotional (%) because only schools with 1) a PK program and 2) a social emotional PK component give these assessments. I could remove PK Only schools from the analysis but I think there's a better way to solve for the issuse.
#
# Also, because this framework score is by nature aggregated based on the performance on each of the individual measures, all measures theoretically will have a high correlation with the actual score. I need to figure out if this is a problem or not.
#
# #### Next Steps
# The next steps are to solve for the null values, add in additonal features I think are relevant, and decide whether or not to pull in historical data prior to SY 2018-19 for the model.
